# %%
from app_with_measurement import evaluate_response

# %%
# Prepare the dataset
test_queries = [
    "What is the importance of skin-to-skin contact for babies, and what should I observe during this time?"
]
expected_responses = [
    "Skin-to-skin contact is crucial for newborns as it helps regulate their body temperature, supports breastfeeding, and enhances bonding. During this time, observe the baby’s breathing, skin color, and temperature. The baby should appear calm, with normal breathing and a steady heartbeat."
]

# %%
test_queries = [
    "What is the importance of skin-to-skin contact for babies, and what should I observe during this time?"
]
expected_responses = [
    "Skin-to-skin contact is crucial for newborns as it helps regulate their body temperature, supports breastfeeding, and enhances bonding. During this time, observe the baby’s breathing, skin color, and temperature. The baby should appear calm, with normal breathing and a steady heartbeat."
]

# %%
evaluate_response(test_queries, expected_responses)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 evaluate_response(test_queries, expected_responses)
#
# File ~/Documents/github_repos/work-projects/my_work/RAG_Setup/backend/app_with_measurement.py:109, in evaluate_response(test_queries, expected_responses)
#     106 faithful_scores = []
#     108 for query, expected in zip(test_queries, expected_responses):
# --> 109     response = process_query(query)
#     111     if response.get("error"):
#     112         print(f"Error processing query '{query}': {response['error']}")
#
# File ~/Documents/github_repos/work-projects/my_work/RAG_Setup/backend/app_with_measurement.py:28, in process_query(query, top_k, similarity_threshold)
#      25     return {"error": "Failed to generate embedding for the query."}
#      27 # Retrieve documents from Pinecone
# ---> 28 results = retrieve_documents(query_embedding)
#      29 if not results['matches']:
#      30     return {"error": "No documents were retrieved."}
#
# File ~/Documents/github_repos/work-projects/my_work/RAG_Setup/backend/app_with_measurement.py:61, in retrieve_documents(query_embedding)
#      59 index = pc.Index(index_name)
#      60 # Query Pinecone index
# ---> 61 results = index.query(
#      62     vector=query_embedding,
#      63     top_k=5,
#      64     include_metadata=True
#      65 )
#      66 return results
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/utils/error_handling.py:11, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#       8 @wraps(func)
#       9 def inner_func(*args, **kwargs):
#      10     try:
# ---> 11         return func(*args, **kwargs)
#      12     except MaxRetryError as e:
#      13         if isinstance(e.reason, ProtocolError):
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/data/index.py:429, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     415 sparse_vector = self._parse_sparse_values_arg(sparse_vector)
#     416 args_dict = self._parse_non_empty_args(
#     417     [
#     418         ("vector", vector),
#    (...)
#     427     ]
#     428 )
# --> 429 response = self._vector_api.query(
#     430     QueryRequest(
#     431         **args_dict,
#     432         _check_type=_check_type,
#     433         **{k: v for k, v in kwargs.items() if k not in _OPENAPI_ENDPOINT_PARAMS},
#     434     ),
#     435     **{k: v for k, v in kwargs.items() if k in _OPENAPI_ENDPOINT_PARAMS},
#     436 )
#     437 return parse_query_response(response)
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/api_client.py:761, in Endpoint.__call__(self, *args, **kwargs)
#     750 def __call__(self, *args, **kwargs):
#     751     """This method is invoked when endpoints are called
#     752     Example:
#     753
#    (...)
#     759
#     760     """
# --> 761     return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/data/api/data_plane_api.py:639, in DataPlaneApi.__init__.<locals>.__query(self, query_request, **kwargs)
#     637 kwargs["_host_index"] = kwargs.get("_host_index")
#     638 kwargs["query_request"] = query_request
# --> 639 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/api_client.py:819, in Endpoint.call_with_http_info(self, **kwargs)
#     816     header_list = self.api_client.select_header_content_type(content_type_headers_list)
#     817     params["header"]["Content-Type"] = header_list
# --> 819 return self.api_client.call_api(
#     820     self.settings["endpoint_path"],
#     821     self.settings["http_method"],
#     822     params["path"],
#     823     params["query"],
#     824     params["header"],
#     825     body=params["body"],
#     826     post_params=params["form"],
#     827     files=params["file"],
#     828     response_type=self.settings["response_type"],
#     829     auth_settings=self.settings["auth"],
#     830     async_req=kwargs["async_req"],
#     831     _check_type=kwargs["_check_return_type"],
#     832     _return_http_data_only=kwargs["_return_http_data_only"],
#     833     _preload_content=kwargs["_preload_content"],
#     834     _request_timeout=kwargs["_request_timeout"],
#     835     _host=_host,
#     836     collection_formats=params["collection_format"],
#     837 )
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/api_client.py:380, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     326 """Makes the HTTP request (synchronous) and returns deserialized data.
#     327
#     328 To make an async_req request, set the async_req parameter.
#    (...)
#     377     then the method will return the response directly.
#     378 """
#     379 if not async_req:
# --> 380     return self.__call_api(
#     381         resource_path,
#     382         method,
#     383         path_params,
#     384         query_params,
#     385         header_params,
#     386         body,
#     387         post_params,
#     388         files,
#     389         response_type,
#     390         auth_settings,
#     391         _return_http_data_only,
#     392         collection_formats,
#     393         _preload_content,
#     394         _request_timeout,
#     395         _host,
#     396         _check_type,
#     397     )
#     399 return self.pool.apply_async(
#     400     self.__call_api,
#     401     (
#    (...)
#     418     ),
#     419 )
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/api_client.py:187, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
# --> 187     raise e
#     189 self.last_response = response_data
#     191 return_data = response_data
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/api_client.py:175, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     171     url = _host + resource_path
#     173 try:
#     174     # perform request and return response
# --> 175     response_data = self.request(
#     176         method,
#     177         url,
#     178         query_params=query_params,
#     179         headers=header_params,
#     180         post_params=post_params,
#     181         body=body,
#     182         _preload_content=_preload_content,
#     183         _request_timeout=_request_timeout,
#     184     )
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/api_client.py:460, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     450     return self.rest_client.OPTIONS(
#     451         url,
#     452         query_params=query_params,
#    (...)
#     457         body=body,
#     458     )
#     459 elif method == "POST":
# --> 460     return self.rest_client.POST(
#     461         url,
#     462         query_params=query_params,
#     463         headers=headers,
#     464         post_params=post_params,
#     465         _preload_content=_preload_content,
#     466         _request_timeout=_request_timeout,
#     467         body=body,
#     468     )
#     469 elif method == "PUT":
#     470     return self.rest_client.PUT(
#     471         url,
#     472         query_params=query_params,
#    (...)
#     477         body=body,
#     478     )
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/rest.py:345, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     335 def POST(
#     336     self,
#     337     url,
#    (...)
#     343     _request_timeout=None,
#     344 ):
# --> 345     return self.request(
#     346         "POST",
#     347         url,
#     348         headers=headers,
#     349         query_params=query_params,
#     350         post_params=post_params,
#     351         _preload_content=_preload_content,
#     352         _request_timeout=_request_timeout,
#     353         body=body,
#     354     )
#
# File ~/miniconda3/envs/snakey/lib/python3.8/site-packages/pinecone/core/openapi/shared/rest.py:279, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     276     if 500 <= r.status <= 599:
#     277         raise ServiceException(http_resp=r)
# --> 279     raise PineconeApiException(http_resp=r)
#     281 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 14 Nov 2024 07:19:31 GMT', 'Content-Type': 'application/json', 'Content-Length': '104', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '459', 'x-pinecone-request-id': '8726342892713038201', 'x-envoy-upstream-service-time': '41', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 1536 does not match the dimension of the index 3072","details":[]}
